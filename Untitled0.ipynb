# %% [markdown]
# <a href="https://colab.research.google.com/github/dxt42250/HW1_70074425_TUMMALA/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# printing the title
print("Plot the loss and accuracy for both training data and validation data using the history object in the source code.")

# Load the MNIST dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Normalize the pixel values to the range [0, 1]
train_images = train_images / 255.0
test_images = test_images / 255.0

# Reshape the images to match the input shape of the model
train_images = train_images.reshape(train_images.shape[0], 784)
test_images = test_images.reshape(test_images.shape[0], 784)

# Define the model architecture
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(784,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# Plot the loss and accuracy for both training and validation data
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# printing the title
print("Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.")


# Select one image from the test data
image = test_images[0]

# Plot the image
plt.imshow(image.reshape(28, 28))
plt.show()

# Do inference on the image
prediction = model.predict(image.reshape(1, 784))

# Print the prediction
print("Model Prediction:", prediction.argmax())


# printing the title
print("We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.")

# Change the number of hidden layers and the activation function
model_new = keras.Sequential([
    keras.layers.Dense(128, activation='tanh', input_shape=(784,)),
    keras.layers.Dense(64, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model_new.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_new = model_new.fit(train_images, train_labels, epochs=10, validation_data=(test_images, test_labels))

# printing the title
print("Run the same code without scaling the images and check the performance?")


# Run the same code without scaling the images
model_no_scaling = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(784,)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model_no_scaling.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history_no_scaling = model_no_scaling.fit(train_images * 255.0, train_labels, epochs=10, validation_data=(test_images * 255.0, test_labels))
# Out:
# Plot the loss and accuracy for both training data and validation data using the history object in the source code.
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2845 - accuracy: 0.9177 - val_loss: 0.1529 - val_accuracy: 0.9523
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1285 - accuracy: 0.9611 - val_loss: 0.1181 - val_accuracy: 0.9632
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0919 - accuracy: 0.9714 - val_loss: 0.0986 - val_accuracy: 0.9705
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0712 - accuracy: 0.9782 - val_loss: 0.1011 - val_accuracy: 0.9682
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0595 - accuracy: 0.9809 - val_loss: 0.0901 - val_accuracy: 0.9718
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.1008 - val_accuracy: 0.9717
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0402 - accuracy: 0.9870 - val_loss: 0.0963 - val_accuracy: 0.9727
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0352 - accuracy: 0.9885 - val_loss: 0.0890 - val_accuracy: 0.9773
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0299 - accuracy: 0.9903 - val_loss: 0.0955 - val_accuracy: 0.9735
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0259 - accuracy: 0.9913 - val_loss: 0.1169 - val_accuracy: 0.9692
# Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
# 1/1 [==============================] - 0s 53ms/step
# Model Prediction: 7
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2610 - accuracy: 0.9245 - val_loss: 0.1484 - val_accuracy: 0.9554
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1216 - accuracy: 0.9633 - val_loss: 0.1145 - val_accuracy: 0.9656
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0834 - accuracy: 0.9753 - val_loss: 0.1017 - val_accuracy: 0.9690
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.0996 - val_accuracy: 0.9696
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.0807 - val_accuracy: 0.9742
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0360 - accuracy: 0.9887 - val_loss: 0.0881 - val_accuracy: 0.9731
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0279 - accuracy: 0.9910 - val_loss: 0.0832 - val_accuracy: 0.9767
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0235 - accuracy: 0.9928 - val_loss: 0.0823 - val_accuracy: 0.9761
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.0864 - val_accuracy: 0.9745
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0916 - val_accuracy: 0.9750
# Run the same code without scaling the images and check the performance?
# Epoch 1/10
# 1875/1875 [==============================] - 47s 3ms/step - loss: 1.4965 - accuracy: 0.8129 - val_loss: 0.4162 - val_accuracy: 0.8975
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3911 - accuracy: 0.9041 - val_loss: 0.3232 - val_accuracy: 0.9164
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3377 - accuracy: 0.9155 - val_loss: 0.3341 - val_accuracy: 0.9197
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2860 - accuracy: 0.9278 - val_loss: 0.2678 - val_accuracy: 0.9302
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2387 - accuracy: 0.9374 - val_loss: 0.2414 - val_accuracy: 0.9373
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2053 - accuracy: 0.9446 - val_loss: 0.2147 - val_accuracy: 0.9441
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1837 - accuracy: 0.9494 - val_loss: 0.1995 - val_accuracy: 0.9488
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1668 - accuracy: 0.9538 - val_loss: 0.1865 - val_accuracy: 0.9514
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1548 - accuracy: 0.9558 - val_loss: 0.2114 - val_accuracy: 0.9417
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1462 - accuracy: 0.9590 - val_loss: 0.1955 - val_accuracy: 0.9517
